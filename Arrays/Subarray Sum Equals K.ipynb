# %% [markdown]
# #Subarray Sum Equals K
#
# You are given an array of integers and a target sum. Write a program to find the total number of continuous subarrays in the given array whose sum equals the target sum.
#
# Input Format:
#
# The first line contains an integer n, denoting the size of the array.
# The second line contains n space-separated integers, representing the elements of the array.
# The third line contains an integer k, representing the target sum.
# Output Format:
#
# Output a single integer, representing the total number of continuous subarrays whose sum equals the target sum.
# Constraints:
#
# 1 <= nums.length <= 2 * 10^4
# -1000 <= nums[i] <= 1000
# -10^7 <= k <= 10^7
#
# Input and Output Format:
#
# Refer sample input and output for formatting specifications.
#
# [All text in bold corresponds to input and the rest corresponds to output]
#
# Sample Input and Output:
#
# Enter the size of the array:
#
# 7
# Enter 7 elements of the array:
# 3 4 7 2 -3 1 4
# Enter the target sum:
#
# 6
# Number of subarrays with sum 6: 1

# %%
def subarraySum(nums, k):
    count = 0
    sum_map = {0: 1}
    curr_sum = 0

    for num in nums:
        curr_sum += num
        count += sum_map.get(curr_sum - k, 0)
        sum_map[curr_sum] = sum_map.get(curr_sum, 0) + 1

    return count

def main():
    n = int(input("Enter the size of the array: "))
    print("Enter", n, "elements of the array:")
    nums = list(map(int, input().split()))
    k = int(input("Enter the target sum: "))

    count = subarraySum(nums, k)
    print("Number of subarrays with sum", k, ":", count)

if __name__ == "__main__":
    main()
# Out:
# Enter the size of the array: 5
# Enter 5 elements of the array:
# 10 20 30 40 50
# Enter the target sum: 60
# Number of subarrays with sum 60 : 1
